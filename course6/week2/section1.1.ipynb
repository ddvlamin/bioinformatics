# %%
import sys

sys.path.append('/Users/ddvlamin/bioinformatics/course6/')

from common.suffix_tree import SuffixTree

# %%
suffix_tree = SuffixTree("panamabananas")

# %%
suffix_tree._root.children
# Out:
# {'p': panamabananas$|-1|0|14:,
#  'a': a|-1|1|1:n-m-b-s,
#  'n': na|-1|2|2:m-n-s,
#  'm': mabananas$|-1|4|10:,
#  'b': bananas$|-1|6|8:,
#  's': s$|-1|12|2:,
#  '$': $|-1|13|1:}

# %%
def suffix_array(text):
    return [tpl[1] for tpl in sorted([(text[i:],i) for i in range(len(text))])]

# %%
text = "AACGATAGCGGTAGA$"
print(suffix_array(text))
# Out:
# [15, 14, 0, 1, 12, 6, 4, 2, 8, 13, 3, 7, 9, 10, 11, 5]

# %%
with open("../data/dataset_310_2.txt") as fin:
    text = fin.read().strip()
    print(suffix_array(text))
# Out:
# [929, 271, 272, 273, 700, 274, 180, 17, 367, 822, 265, 392, 535, 347, 32, 290, 302, 671, 251, 319, 451, 353, 695, 701, 651, 625, 275, 708, 676, 473, 181, 664, 18, 613, 185, 368, 84, 338, 823, 266, 819, 532, 381, 234, 521, 54, 912, 393, 116, 330, 690, 468, 78, 280, 536, 759, 570, 606, 288, 910, 688, 286, 284, 495, 348, 384, 879, 846, 295, 681, 497, 922, 68, 926, 350, 636, 788, 257, 444, 63, 11, 721, 587, 33, 291, 771, 639, 303, 672, 432, 791, 312, 113, 660, 717, 252, 386, 415, 881, 320, 510, 452, 426, 158, 354, 854, 696, 208, 553, 465, 919, 60, 702, 780, 765, 753, 260, 618, 652, 239, 449, 611, 310, 751, 237, 447, 626, 436, 276, 628, 484, 668, 709, 102, 888, 892, 900, 726, 747, 42, 192, 134, 677, 474, 834, 848, 360, 182, 155, 665, 402, 841, 19, 614, 186, 297, 827, 369, 85, 683, 421, 339, 524, 712, 373, 705, 462, 131, 824, 216, 267, 96, 490, 499, 602, 438, 594, 871, 645, 820, 533, 278, 382, 66, 924, 235, 400, 522, 55, 913, 803, 219, 514, 224, 105, 14, 57, 915, 805, 48, 394, 117, 656, 54
# ...
